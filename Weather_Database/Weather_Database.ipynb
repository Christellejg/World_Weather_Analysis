# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key


city_data = []

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
import csv
import os
from citipy import citipy

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/christellegeorges/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/christellegeorges/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)
# WARNING: You are using pip version 22.0.2; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/christellegeorges/opt/anaconda3/envs/PythonData/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import os
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0550f3bc2ad9460a3f3a030af53ee996

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
       # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bitlis
# Processing Record 2 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 1 | ambon
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | sabzevar
# Processing Record 9 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 1 | champerico
# Processing Record 11 of Set 1 | paamiut
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | tual
# Processing Record 15 of Set 1 | qui nhon
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | margate
# Processing Record 18 of Set 1 | easton
# Processing Record 19 of Set 1 | labuhan
# Processing Record 20 of Set 1 | acu
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | bubaque
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | berlevag
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | suicheng
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | cherskiy
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | safranbolu
# Processing Record 38 of Set 1 | bathsheba
# Processing Record 39 of Set 1 | manokwari
# Processing Record 40 of Set 1 | puerto escondido
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | rosarito
# Processing Record 45 of Set 1 | alyangula
# Processing Record 46 of Set 1 | waipawa
# Processing Record 47 of Set 1 | laramie
# Processing Record 48 of Set 1 | provideniya
# Processing Record 49 of Set 1 | pundaguitan
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | la rioja
# Processing Record 2 of Set 2 | dandong
# Processing Record 3 of Set 2 | swellendam
# Processing Record 4 of Set 2 | fomboni
# Processing Record 5 of Set 2 | te anau
# Processing Record 6 of Set 2 | vanimo
# Processing Record 7 of Set 2 | porong
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | srandakan
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | trofors
# Processing Record 12 of Set 2 | vila velha
# Processing Record 13 of Set 2 | jutai
# Processing Record 14 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | kemijarvi
# Processing Record 17 of Set 2 | nexo
# Processing Record 18 of Set 2 | hamilton
# Processing Record 19 of Set 2 | guadalupe victoria
# Processing Record 20 of Set 2 | borgarnes
# Processing Record 21 of Set 2 | ostersund
# Processing Record 22 of Set 2 | grand gaube
# Processing Record 23 of Set 2 | lompoc
# Processing Record 24 of Set 2 | san carlos de bariloche
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 2 | dicabisagan
# Processing Record 29 of Set 2 | plettenberg bay
# Processing Record 30 of Set 2 | xichang
# Processing Record 31 of Set 2 | hualmay
# Processing Record 32 of Set 2 | touros
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | samarai
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | ambilobe
# Processing Record 40 of Set 2 | cayenne
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | tres lagoas
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | forestville
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | bruhl
# Processing Record 49 of Set 2 | proddatur
# Processing Record 50 of Set 2 | tura
# Processing Record 1 of Set 3 | northam
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | shimoda
# Processing Record 4 of Set 3 | nhulunbuy
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 3 | lata
# Processing Record 8 of Set 3 | ponta delgada
# Processing Record 9 of Set 3 | high level
# Processing Record 10 of Set 3 | los llanos de aridane
# Processing Record 11 of Set 3 | tamiahua
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | bakchar
# Processing Record 15 of Set 3 | mingguang
# Processing Record 16 of Set 3 | omsukchan
# Processing Record 17 of Set 3 | lensk
# Processing Record 18 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | leeton
# Processing Record 21 of Set 3 | vasterhaninge
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | namatanai
# Processing Record 24 of Set 3 | vanavara
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | spornoye
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | half moon bay
# Processing Record 29 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 3 | bajo baudo
# City not found. Skipping...
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | lebyazhye
# Processing Record 33 of Set 3 | khunti
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 3 | imbituba
# Processing Record 36 of Set 3 | ahipara
# Processing Record 37 of Set 3 | cabedelo
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | rafaela
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | whitehorse
# Processing Record 44 of Set 3 | guia de isora
# Processing Record 45 of Set 3 | gisborne
# Processing Record 46 of Set 3 | cockburn town
# Processing Record 47 of Set 3 | hofn
# Processing Record 48 of Set 3 | ilovlya
# Processing Record 49 of Set 3 | omboue
# Processing Record 50 of Set 3 | cartagena
# Processing Record 1 of Set 4 | volokolamsk
# Processing Record 2 of Set 4 | takoradi
# Processing Record 3 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | qaanaaq
# Processing Record 6 of Set 4 | begoro
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | riviere-au-renard
# Processing Record 9 of Set 4 | laguna
# Processing Record 10 of Set 4 | arraial do cabo
# Processing Record 11 of Set 4 | henties bay
# Processing Record 12 of Set 4 | yellowknife
# Processing Record 13 of Set 4 | puerto ayora
# Processing Record 14 of Set 4 | beloha
# Processing Record 15 of Set 4 | port alfred
# Processing Record 16 of Set 4 | deh rawud
# City not found. Skipping...
# Processing Record 17 of Set 4 | gidam
# Processing Record 18 of Set 4 | constitucion
# Processing Record 19 of Set 4 | inhambane
# Processing Record 20 of Set 4 | kozulka
# Processing Record 21 of Set 4 | porbandar
# Processing Record 22 of Set 4 | vila
# Processing Record 23 of Set 4 | carbonia
# Processing Record 24 of Set 4 | kenai
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | kaeo
# Processing Record 27 of Set 4 | teya
# Processing Record 28 of Set 4 | lima
# Processing Record 29 of Set 4 | santa lucia
# Processing Record 30 of Set 4 | cooma
# Processing Record 31 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 4 | batouri
# Processing Record 33 of Set 4 | porto santo
# Processing Record 34 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 4 | rocha
# Processing Record 36 of Set 4 | valley station
# Processing Record 37 of Set 4 | kathmandu
# Processing Record 38 of Set 4 | balkhash
# Processing Record 39 of Set 4 | fuyu
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | hun
# Processing Record 42 of Set 4 | pangnirtung
# Processing Record 43 of Set 4 | mandalgovi
# Processing Record 44 of Set 4 | sapa
# Processing Record 45 of Set 4 | abiy adi
# City not found. Skipping...
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | khatanga
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | jaisalmer
# Processing Record 50 of Set 4 | ericeira
# Processing Record 1 of Set 5 | flin flon
# Processing Record 2 of Set 5 | bud
# Processing Record 3 of Set 5 | vestmannaeyjar
# Processing Record 4 of Set 5 | registro
# Processing Record 5 of Set 5 | eureka
# Processing Record 6 of Set 5 | mont-dore
# Processing Record 7 of Set 5 | pampa
# Processing Record 8 of Set 5 | makakilo city
# Processing Record 9 of Set 5 | saskylakh
# Processing Record 10 of Set 5 | raudeberg
# Processing Record 11 of Set 5 | san patricio
# Processing Record 12 of Set 5 | chicama
# Processing Record 13 of Set 5 | cidreira
# Processing Record 14 of Set 5 | orchard homes
# Processing Record 15 of Set 5 | north bend
# Processing Record 16 of Set 5 | guarapari
# Processing Record 17 of Set 5 | severo-kurilsk
# Processing Record 18 of Set 5 | marsa matruh
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | dongsheng
# Processing Record 21 of Set 5 | sarangani
# Processing Record 22 of Set 5 | sfantu gheorghe
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | narsaq
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | quang ngai
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | lasa
# Processing Record 30 of Set 5 | saint-georges
# Processing Record 31 of Set 5 | bonthe
# Processing Record 32 of Set 5 | viedma
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | mattru
# Processing Record 35 of Set 5 | lebu
# Processing Record 36 of Set 5 | davila
# Processing Record 37 of Set 5 | faanui
# Processing Record 38 of Set 5 | manthani
# Processing Record 39 of Set 5 | nalut
# Processing Record 40 of Set 5 | la paz
# Processing Record 41 of Set 5 | shebalino
# Processing Record 42 of Set 5 | west wendover
# Processing Record 43 of Set 5 | borovoy
# Processing Record 44 of Set 5 | mainpuri
# Processing Record 45 of Set 5 | coquimbo
# Processing Record 46 of Set 5 | esna
# Processing Record 47 of Set 5 | nizwa
# Processing Record 48 of Set 5 | misratah
# Processing Record 49 of Set 5 | east london
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | monrovia
# Processing Record 2 of Set 6 | broken hill
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | mora
# Processing Record 5 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 6 | mount isa
# Processing Record 7 of Set 6 | kuala terengganu
# Processing Record 8 of Set 6 | beringovskiy
# Processing Record 9 of Set 6 | barao de melgaco
# Processing Record 10 of Set 6 | aliverion
# City not found. Skipping...
# Processing Record 11 of Set 6 | amahai
# Processing Record 12 of Set 6 | husavik
# Processing Record 13 of Set 6 | raga
# Processing Record 14 of Set 6 | port hardy
# Processing Record 15 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | asau
# Processing Record 18 of Set 6 | chanthaburi
# Processing Record 19 of Set 6 | karratha
# Processing Record 20 of Set 6 | catamarca
# Processing Record 21 of Set 6 | olga
# Processing Record 22 of Set 6 | villa carlos paz
# Processing Record 23 of Set 6 | krasnoselkup
# Processing Record 24 of Set 6 | tsiroanomandidy
# Processing Record 25 of Set 6 | ulladulla
# Processing Record 26 of Set 6 | alta floresta
# Processing Record 27 of Set 6 | balabac
# Processing Record 28 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 6 | valentin gomez farias
# Processing Record 30 of Set 6 | georgetown
# Processing Record 31 of Set 6 | olafsvik
# Processing Record 32 of Set 6 | bandarbeyla
# Processing Record 33 of Set 6 | chabahar
# Processing Record 34 of Set 6 | codrington
# Processing Record 35 of Set 6 | aksarka
# Processing Record 36 of Set 6 | kadoshkino
# Processing Record 37 of Set 6 | catumbela
# Processing Record 38 of Set 6 | abu kamal
# Processing Record 39 of Set 6 | diapaga
# Processing Record 40 of Set 6 | matay
# Processing Record 41 of Set 6 | andenes
# Processing Record 42 of Set 6 | newport
# Processing Record 43 of Set 6 | verkhnevilyuysk
# Processing Record 44 of Set 6 | grootfontein
# Processing Record 45 of Set 6 | sola
# Processing Record 46 of Set 6 | sorrento
# Processing Record 47 of Set 6 | khartoum
# Processing Record 48 of Set 6 | trairi
# Processing Record 49 of Set 6 | sumy
# Processing Record 50 of Set 6 | bonavista
# Processing Record 1 of Set 7 | taoudenni
# Processing Record 2 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 7 | hithadhoo
# Processing Record 4 of Set 7 | sao filipe
# Processing Record 5 of Set 7 | ilulissat
# Processing Record 6 of Set 7 | newnan
# Processing Record 7 of Set 7 | am timan
# Processing Record 8 of Set 7 | mar del plata
# Processing Record 9 of Set 7 | kaniama
# Processing Record 10 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 11 of Set 7 | onega
# Processing Record 12 of Set 7 | bouna
# Processing Record 13 of Set 7 | khonsar
# City not found. Skipping...
# Processing Record 14 of Set 7 | pevek
# Processing Record 15 of Set 7 | barcelona
# Processing Record 16 of Set 7 | mehamn
# Processing Record 17 of Set 7 | maningrida
# Processing Record 18 of Set 7 | barcelos
# Processing Record 19 of Set 7 | pitiquito
# Processing Record 20 of Set 7 | sortino
# Processing Record 21 of Set 7 | sao sebastiao
# Processing Record 22 of Set 7 | sampit
# Processing Record 23 of Set 7 | wilkie
# Processing Record 24 of Set 7 | larsnes
# Processing Record 25 of Set 7 | havre-saint-pierre
# Processing Record 26 of Set 7 | zhob
# Processing Record 27 of Set 7 | banjar
# Processing Record 28 of Set 7 | lagoa
# Processing Record 29 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 7 | nikolayevsk-na-amure
# Processing Record 31 of Set 7 | mitu
# Processing Record 32 of Set 7 | khuzdar
# Processing Record 33 of Set 7 | gat
# Processing Record 34 of Set 7 | roma
# Processing Record 35 of Set 7 | west bay
# Processing Record 36 of Set 7 | pomerode
# Processing Record 37 of Set 7 | negotin
# Processing Record 38 of Set 7 | naze
# Processing Record 39 of Set 7 | agaro
# Processing Record 40 of Set 7 | acutzilapan
# City not found. Skipping...
# Processing Record 41 of Set 7 | pala
# Processing Record 42 of Set 7 | kargasok
# Processing Record 43 of Set 7 | darien
# Processing Record 44 of Set 7 | pisco
# Processing Record 45 of Set 7 | esperance
# Processing Record 46 of Set 7 | sao paulo de olivenca
# Processing Record 47 of Set 7 | laurel
# Processing Record 48 of Set 7 | fayaoue
# Processing Record 49 of Set 7 | xinmin
# Processing Record 50 of Set 7 | leningradskiy
# Processing Record 1 of Set 8 | scalloway
# City not found. Skipping...
# Processing Record 2 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 8 | barbosa ferraz
# Processing Record 4 of Set 8 | sosnovo-ozerskoye
# Processing Record 5 of Set 8 | kuytun
# Processing Record 6 of Set 8 | honiara
# Processing Record 7 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 8 of Set 8 | talnakh
# Processing Record 9 of Set 8 | luderitz
# Processing Record 10 of Set 8 | bambous virieux
# Processing Record 11 of Set 8 | arica
# Processing Record 12 of Set 8 | tisul
# Processing Record 13 of Set 8 | atar
# Processing Record 14 of Set 8 | jalu
# Processing Record 15 of Set 8 | bintulu
# Processing Record 16 of Set 8 | isangel
# Processing Record 17 of Set 8 | presidencia roque saenz pena
# Processing Record 18 of Set 8 | eldorado
# Processing Record 19 of Set 8 | flinders
# Processing Record 20 of Set 8 | senmonorom
# City not found. Skipping...
# Processing Record 21 of Set 8 | prince rupert
# Processing Record 22 of Set 8 | yumen
# Processing Record 23 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 8 | simpang
# Processing Record 25 of Set 8 | porto novo
# Processing Record 26 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 27 of Set 8 | curvelo
# Processing Record 28 of Set 8 | port keats
# Processing Record 29 of Set 8 | khovu-aksy
# Processing Record 30 of Set 8 | gao
# Processing Record 31 of Set 8 | cap-aux-meules
# Processing Record 32 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 8 | necochea
# Processing Record 34 of Set 8 | sisimiut
# Processing Record 35 of Set 8 | basco
# Processing Record 36 of Set 8 | artyom
# Processing Record 37 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 8 | hervey bay
# Processing Record 39 of Set 8 | harrison
# Processing Record 40 of Set 8 | yulara
# Processing Record 41 of Set 8 | north platte
# Processing Record 42 of Set 8 | soure
# Processing Record 43 of Set 8 | rosetta
# Processing Record 44 of Set 8 | conakry
# Processing Record 45 of Set 8 | caetite
# Processing Record 46 of Set 8 | changtu

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
